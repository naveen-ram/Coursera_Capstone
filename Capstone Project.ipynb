# %% [markdown]
# # Capston Project Notebook
# ## This notebook is used for Naveen's data science capstone project on the battle of the neighborhoods of Toronto
# #### Author: Naveen Ram Date: 11/09/2019

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
import json, requests
url = 'https://api.foursquare.com/v2/venues/4b630eb4f964a5203b602ae3'

params = dict(
  client_id='WMOW0BTP12H4ELYHMYSF4PJSJ0VM5BWO3NQCTLQT1QCEYSXM',
  client_secret='RGZW3UBF5JMOSGT5A2FZY5ZILIRSGRBYHFLZBTZKJLEK52ZK',
  v='20191109',
  ll='42.492491, -71.537305',
  query='coffee',
  limit=1
)
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)

# %%
data
# Out:
# {'meta': {'code': 200, 'requestId': '5dc72052bcbf7a003912ebf7'},
#  'response': {'venue': {'id': '4b630eb4f964a5203b602ae3',
#    'name': "Nancy's Air Field Café",
#    'contact': {'phone': '9788973934', 'formattedPhone': '(978) 897-3934'},
#    'location': {'address': '302 Boxboro Rd',
#     'lat': 42.46206986728757,
#     'lng': -71.51711302354485,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 42.46206986728757,
#       'lng': -71.51711302354485}],
#     'distance': 3770,
#     'postalCode': '01775',
#     'cc': 'US',
#     'city': 'Stow',
#     'state': 'MA',
#     'country': 'United States',
#     'formattedAddress': ['302 Boxboro Rd', 'Stow, MA 01775', 'United States']},
#    'canonicalUrl': 'https://foursquare.com/v/nancys-air-field-caf%C3%A9/4b630eb4f964a5203b602ae3',
#    'categories': [{'id': '4bf58dd8d48988d16d941735',
#      'name': 'Café',
#      'pluralName': 'Cafés',
#      'shortName': 'Café',
# ...
